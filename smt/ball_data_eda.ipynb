# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(14,12)})
import matplotlib.pyplot as plt

# %%
ball_pos = pd.read_csv("D:\\new_downloads\SMT-Data-Challenge\SMT-Data-Challenge\\ball_pos.csv")
ball_pos
# Out:
#                      game_str  play_id  timestamp  ball_position_x  \
# 0        1900_01_TeamKJ_TeamB        1    20549.0        -2.432727
# 1        1900_01_TeamKJ_TeamB        1    20582.0        -2.272266
# 2        1900_01_TeamKJ_TeamB        1    20615.0        -2.125386
# 3        1900_01_TeamKJ_TeamB        1    20648.0        -1.992090
# 4        1900_01_TeamKJ_TeamB        1    20681.0        -1.872372
# ...                       ...      ...        ...              ...
# 785036  1903_32_TeamNB_TeamA1      166  5438977.0        99.407700
# 785037  1903_32_TeamNB_TeamA1      166  5439027.0       100.734900
# 785038  1903_32_TeamNB_TeamA1      166  5439077.0       102.068100
# 785039  1903_32_TeamNB_TeamA1      166  5439127.0       103.407000
# 785040  1903_32_TeamNB_TeamA1      166  5439177.0       104.751900
#
#         ball_position_y  ball_position_z
# 0               57.4860         7.292670
# 1               53.2614         7.030620
# ...

# %%
ax = sns.displot(ball_pos, x="ball_position_x")

# %%
ax = sns.displot(ball_pos, x="ball_position_y")

# %%
ax = sns.displot(ball_pos, x="ball_position_z")

# %%
ax = sns.displot(ball_pos, x="timestamp")
