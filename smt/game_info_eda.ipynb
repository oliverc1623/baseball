# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(14,12)})
import matplotlib.pyplot as plt

# %%
game_info = pd.read_csv("D:\\new_downloads\SMT-Data-Challenge\SMT-Data-Challenge\\game_info.csv")
game_info
# Out:
#                     game_str home_team away_team  at_bat  play_per_game  \
# 0       1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              2
# 1       1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              3
# 2       1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              4
# 3       1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              5
# 4       1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              6
# ...                      ...       ...       ...     ...            ...
# 26310  1903_32_TeamNB_TeamA1    TeamA1    TeamNB    54.0            166
# 26311  1903_32_TeamNB_TeamA1    TeamA1    TeamNB    54.0            167
# 26312  1903_32_TeamNB_TeamA1    TeamA1    TeamNB    54.0            168
# 26313  1903_32_TeamNB_TeamA1    TeamA1    TeamNB    54.0            169
# 26314  1903_32_TeamNB_TeamA1    TeamA1    TeamNB    55.0            170
#
#        inning top_bottom_inning  pitcher  catcher  first_base  second_base  \
# ...

# %%
game1 = game_info[game_info['game_str']=='1900_01_TeamKJ_TeamB']
game1.head(30)
# Out:
#                 game_str home_team away_team  at_bat  play_per_game  inning  \
# 0   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              2       1
# 1   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              3       1
# 2   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              4       1
# 3   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              5       1
# 4   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              6       1
# 5   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              7       1
# 6   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN              8       1
# 7   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN             10       1
# 8   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN             11       1
# 9   1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN             13       1
# 10  1900_01_TeamKJ_TeamB     TeamB    TeamKJ     NaN             14       1
# ...
